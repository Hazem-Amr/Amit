# %%
print("This is a simple Jupyter Notebook inside python-for-ml.")
# Out:
# This is a simple Jupyter Notebook inside python-for-ml.

# %%
a = 5
b = 7
print("The sum is:", a + b)
# Out:
# The sum is: 12
